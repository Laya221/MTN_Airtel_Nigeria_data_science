# %%
import pandas as pd

# Load your Facebook dataset (update with your actual file path)
file_path = "final_airtel.csv"
df = pd.read_csv(file_path)

# Ensure text columns are strings and handle NaN values
df.fillna("", inplace=True)

# Define search terms
search_terms = [ "airtel app","app","application","airtel application","APP","App","Application","AIRTEL application", "Airtel app", "AIrtel app ng", "airtel nigeria app"]

# Filter posts that mention "MyMTN" or "MyMTN app"
posts_with_mymtn = df[df["postDescription"].str.contains("|".join(search_terms), case=False, na=False)]

# Filter comments that mention "MyMTN" or "MyMTN app"
comments_with_mymtn = df[df["commentText"].str.contains("|".join(search_terms), case=False, na=False)]

# Save results
posts_with_mymtn.to_csv("filtered_posts_airtel.csv", index=False)
comments_with_mymtn.to_csv("filtered_comments_airtel.csv", index=False)

# Display summary
print(f"Filtered {len(posts_with_mymtn)} posts and {len(comments_with_mymtn)} comments mentioning 'MyMTN' or 'MyMTN app'.")
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_3752\1184615944.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("", inplace=True)
# Filtered 1070 posts and 950 comments mentioning 'MyMTN' or 'MyMTN app'.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)  # لعرض جميع القيم بدون اختصار

df = pd.read_csv('filtered_comments_airtel.csv')

# استخراج القيم الفريدة وترتيبها أبجديًا
unique_authors = sorted(df['commentAuthor'].dropna().unique())  # إزالة القيم الفارغة إن وجدت

# طباعة القيم الفريدة مرتبة أبجديًا
for author in unique_authors:
    print(author)
# Out:
#  Mrr IB King󱢏
# 'Seun Aromire
# Aaron O Johnmartins
# Abbas Day
# Abbas Khan
# Abdulazeez Abdullahi
# Abdullahi Alburhaan
# Abdullahi Skipper
# Abdur-rasheed Ua
# Abidemi Saka Alalade
# Abubakar Hassan
# Abubakar Ismail Habeeb
# Abubakar Tanimu
# Ada Hernandez
# Adamu Ibrahim
# Adedamola Dayo Adeoy
# Adedokun Olatundun Akinyemi
# Adelaja Sule
# Adenike Morenike
# Adeniran Titilope Rashidat
# Adeshina Gansallo
# Adetola Ifeoluwa
# Adetutu Ashiru
# Adewale T Rachael
# Adewemimo Adunni
# Adeyinka Adeyemi
# Adoga Smart
# Adrienne Jay
# Agbongbn Fakayode Faniyi
# Agbongbn Ifa Faniyi
# Agina-Obu Ida-Iyibo Sunny
# Aham Bu Chukwunedum
# Aileen Hodgson
# Ajewole Loveth
# Ajibe Kumshe
# Ajiboye Temitope Emmanuel
# Aka Blesszo
# Akanni Kabir
# Akingbonmire Oluwadarasimi Deborah
# Akinkuotu Oluwatobieh
# Akinrogun Olaniyi Arshavin
# Akinseyi Toyin Sijuwola
# Akpugo Somtochukwu
# Al Ameen Ummul Khair
# Al-amin Muhammad Abba
# Al-kazim Zubayr
# Alabi Jamiu Jamo
# Alamu Abdulrahman
# Aldrich Amend
# Alfred Offor
# Alh Ahmed Daudu
# Alhaji Isa Zaaki
# Alicia Labaff
# Ama Chris
# Ama Rachi
# Amaechi Sharon
# Amaka Odigwe
# Amanda Chidebe Onwudiwe
# Amara Marvelous
# Amarachi Mercy
# Ambitious David
# Sultan Saddam Joda II
# Sunday Akpore
# Sunday Okonkwo
# Symply Emerald
# Sãñ Drã
# Sên Abdulmateên Jñr
# Sñ Åz Zy
# Tada Hanka Leematukar
# Taiwo Aderinto Adesojiola
# Taiye Suleiman
# Tajudeen Onabisi
# Tatiana Gift
# Tayo Adedeji
# Tella Samumel
# Temilade Nana Aishat
# Temitope Ishola
# The National Movement - TNM Nigeria
# The big joe
# Theodora Chinenye Ugwuoke
# Theophilus Ayodeji
# Timileyin Omorosi
# Timothy Okhuasogie
# Tobiloba Olamilekan
# Tochukwu Okwadike
# Tomilola Alabi
# Tri Sh
# Tuceed Kmk
# Tunde Longe
# Tunde Nugaa
# Töbëë Löbär
# Türäwä ẞrävé
# USman AjiboLa Stam
# Ubong Charles Udongwo
# Uche Odiaka
# Uchechukwu Edith Chinwendu
# Udealor Nzubechukwu Martin
# Udibest Ogbonna
# Udoke Elijah
# Ugochukwu Nzeh
# Umar Ishaq Hassan
# Umar S. Haruna
# Usman Kazaure
# Uzochi Davao
# Van Dijk Frederike Franka
# Verinus Pearl
# Vic Ky
# Vickky-t Taiwo
# Vicky Boy
# Victor Ifeanyi
# Victor Kalu
# Victoria Jesse
# Vik Thoor
# Vivian Enwelani
# Vivian Ezeani
# Wea Lth
# Whyteman Harrison
# Wilson Billy
# Wisdom Elijah Sirwise
# Wizboy DaMi
# Y'all Meet Vic
# Yomi Abayomi
# Young Boss
# Young Sky
# Yøüñg Jøñ
# Zaaki Sakpacha
# Zeal C Ezeh
# Zulaikhoh A. Adeola
# hoodbosskitscomedy
# iam Hephzee to world
# Àjere Alaso Oke
# Âñthóñy Âdèsáñyà Tdk
# Ãhm Slím Dãddi
# Çrä Çk Er 󱢏
# Ølämïde Frøsh
# Ølëñtï adb nation müsiç
# Łëštèr DC
# ۦۦ  ۦۦ
# ۦۦ ۦۦ

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('filtered_comments_airtel.csv')

# Convert the commentTimestamp to datetime
df['commentTimestamp'] = pd.to_datetime(df['commentTimestamp'])

# Extract the month from the timestamp
df['month'] = df['commentTimestamp'].dt.to_period('M')

# Group by month and sentiment, then count the occurrences
sentiment_counts = df.groupby(['month', 'sentiment/finalClassification']).size().unstack(fill_value=0)

# Convert Period to string for plotting
sentiment_counts.index = sentiment_counts.index.astype(str)

# Define a color scheme
colors = {'positive': 'green', 'neutral': 'blue', 'negative': 'red'}

# Plot the data
ax = sentiment_counts.plot(kind='bar', stacked=True, figsize=(14, 8), color=[colors[col] for col in sentiment_counts.columns])

# Add annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    if height > 0:  # Only annotate bars with height > 0
        ax.annotate(f'{int(height)}', (x + width / 2, y + height / 2), ha='center', va='center', fontsize=9, color='white')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Improve title and labels
plt.title('Monthly Sentiment Distribution of Airtel Comments', fontsize=16, pad=20)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Comments', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust legend position and style
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_3752\812305540.py:11: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['month'] = df['commentTimestamp'].dt.to_period('M')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_airtel.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords
categories = {
    "App Stability": [
        "crash", "unresponsive", "freeze", "lag", "slow", "session timeout", "loading issue"
    ],
    "Account Synchronization": [
        "delay", "not updated", "incorrect balance", "missing transaction", "sync issue"
    ],
    "Payment Processing": [
        "failed transaction", "deduction", "duplicate charge", "refund", "receipt issue"
    ]
}

# Function to categorize comments
def categorize_comment(text):
    for category, keywords in categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_comment)

# Filter for MyMTN-related comments
mymtn_keywords =  [ "airtel app","app","application","airtel application","APP","App","Application","AIRTEL application", "Airtel app", "AIrtel app ng", "airtel nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_categorized_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of Comments by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of Comments by Category", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_3752\2188424663.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === App Stability ===
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════╤═════════════════════╤═══════════════╕
# │ commentText                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │ commentAuthor                 │   commentLikesCount │ category      │
# ╞═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════╪═════════════════════╪═══════════════╡
# │ i ported to airtel network almost three weeks ago!!! the experience has been awful to say the least!!! i could not access google and playstore for anything!!! only whatsapp and facebook is working at the slowest speed!!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ Mbanefo Okoye                 │                   1 │ App Stability │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────┼─────────────────────┼───────────────┤
# │ airtel ur network this days is going slow what happen my data just dey finished                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ Ølëñtï adb nation müsiç       │                   1 │ App Stability │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────┼─────────────────────┼───────────────┤
# │ i subscribed on 22nd last month, and used for 2 weeks, since this month the internet in going through or very slow, i don't really understand i have a full network bar and it has been happening for a week now, i changed location it is same, what is the issue, do you now have a cap on data that can be used?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_airtel.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords for User Experience Issues
user_experience_categories = {
    "Authentication": [
        "password", "otp", "one-time password", "verification code", "login issue", "account locked"
    ],
    "User Interface": [
        "cluttered", "too many ads", "difficult to use", "navigation issue", "hard to find", "menu problem"
    ],
    "Updates & Maintenance": [
        "update issue", "forced update", "app update", "compatibility issue", "maintenance", "service interruption"
    ]
}

# Function to categorize comments based on user experience issues
def categorize_user_experience(text):
    for category, keywords in user_experience_categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_user_experience)

# Filter for MyMTN-related comments
mymtn_keywords = [ "airtel app","app","application","airtel application","APP","App","Application","AIRTEL application", "Airtel app", "AIrtel app ng", "airtel nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Remove "Other" category
df_mymtn_filtered = df_mymtn_filtered[df_mymtn_filtered["category"] != "Other"]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_user_experience_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of User Experience Issues in MyMTN App", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of User Experience Issues", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in user_experience_categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_3752\3917049129.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === Authentication ===
# ╒══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════╤═════════════════════╤════════════════╕
# │ commentText                                                                                                                                                                                                                                                                                      │ commentAuthor                       │   commentLikesCount │ category       │
# ╞══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════╪═════════════════════╪════════════════╡
# │ i have been waiting for the otp to complete my airtel app, why are you not sending the otp                                                                                                                                                                                                       │ Emmanuel Pedro                      │                   1 │ Authentication │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┼────────────────┤
# │ my favorite sim card airtel please 🙏                                                                                                                                                                                                                                                            │ Muhammad D Kaura                    │                   0 │ Authentication │
# │ please 🙏 i dey here libya 🇱🇾 country my airtel sim card is with me here libya                                                                                                                                                                                                                   │                                     │                     │                │
# │                                                                                                                                                                                                                                                                                                  │                                     │                     │                │
# │ and i want log my whatsapp my gmail my moniepoint account's                                                                                                                                                                                                                                      │                                     │                     │                │
# │                                                                                                                                                                                                                                                                                                  │                                     │                     │                │
# │ and i can not received otp code be cause the sim card is emergency no nigerian network here libya 🇱🇾                                                                                                                                                                                             │                                     │                     │                │
# │                                                                                                                                                                                                                                                                                                  │                                     │                     │                │
# │ so please how can i received my sim card otp code message with out a network?                                                                                                                                                                                                                    │                                     │                     │                │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┼────────────────┤
# │ what’s so happy about it? that i’m trying to make a transfer from my union bank and they are sending you otp and your foolish network is down???                                                                                                                                                 │ Kaycee Okwudinanka                  │                   0 │ Authentication │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┼────────────────┤
# │ airtel nigeria please look into my issue, i ported my 9mobile sim to airtel network since mid 2024, but ever since i've been having difficulties receiving otp messages. currently i want register my banking mobile app but i couldn't receive the otp sent to me. please help resolve my issue │ The National Movement - TNM Nigeria │                   0 │ Authentication │
# ╘══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════╧═════════════════════╧════════════════╛
#
# === Updates & Maintenance ===
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════╤═════════════════════╤═══════════════════════╕
# │ commentText                                                                                                                                                                   │ commentAuthor                       │   commentLikesCount │ category              │
# ╞═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════╪═════════════════════╪═══════════════════════╡
# │ the forgotten technology.                                                                                                                                                     │ International Insulation Engineers. │                   0 │ Updates & Maintenance │
# │ insulation is a key component of any industrial or commercial building project, as it can improve the energy efficiency, comfort, and safety of the occupants, and equipment. │                                     │                     │                       │
# │ however, not all insulation materials are created equal. some may have drawbacks such as low fire resistance, poor sound absorption, or environmental concerns.               │                                     │                     │                       │
# │ we're here for you, to help you maintain an eco-friendly environment.                                                                                                         │                                     │                     │                       │
# │ we're international insulation engineers.                                                                                                                                     │                                     │                     │                       │
# │         let us handle your industrial and commercial insulation projects, labour supply, maintenance jobs, and hvac systems                                                   │                                     │                     │                       │
# │ email:                                                                                                                                                                        │                                     │                     │                       │
# │ internationalinsulationengrs@gmail.com                                                                                                                                        │                                     │                     │                       │
# │ whatsapp: +2348068387343                                                                                                                                                      │                                     │                     │                       │
# │                                                                                                                                                                               │                                     │                     │                       │
# │ location is no barrier.                                                                                                                                                       │                                     │                     │                       │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┼───────────────────────┤
# │ my airtel 5g is not working since yesterday, i don't know if it's maintenance but you guys should communicate when such will happen. i can't even do anything on my phone.    │ Is Real                             │                   0 │ Updates & Maintenance │
# ╘═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════╧═════════════════════╧═══════════════════════╛

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_airtel.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords for Customer Support
customer_support_categories = {
    "In-app Support": [
        "self-service", "response time", "no response", "customer support", "chatbot", "live support", "help center"
    ],
    "Issue Resolution": [
        "ticket", "support tracking", "issue report", "no resolution", "problem not fixed", "open support ticket"
    ]
}

# Function to categorize comments based on customer support issues
def categorize_customer_support(text):
    for category, keywords in customer_support_categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_customer_support)

# Filter for MyMTN-related comments
mymtn_keywords = [ "airtel app","app","application","airtel application","APP","App","Application","AIRTEL application", "Airtel app", "AIrtel app ng", "airtel nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Remove "Other" category
df_mymtn_filtered = df_mymtn_filtered[df_mymtn_filtered["category"] != "Other"]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_customer_support_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of Customer Support Issues in MyMTN App", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of Customer Support Issues", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in customer_support_categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_3752\16718912.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === In-app Support ===
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════╤═════════════════════╤════════════════╕
# │ commentText                                                                                                                                                                                                                                               │ commentAuthor             │   commentLikesCount │ category       │
# ╞═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════╪═════════════════════╪════════════════╡
# │ my unlimited 20 bundle usually got disconnected for few hours almost everyday. what's the problem. i lodge complaint via whatsapp but no response from airtel                                                                                             │ Abubakar Tanimu           │                   2 │ In-app Support │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────────────────┼────────────────┤
# │ me i have a problem any time i bought data i can use to do anything except whatsapp i have try to call customer care but no response 😢                                                                                                                   │ Omolara Gold              │                   0 │ In-app Support │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────────────────┼────────────────┤
# │ airtel nigeria                                                                                                                                                                                                                                            │ Olamide Oladejo           │                   0 │ In-app Support │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ newly bought and registered line for 4 days now. i can't make call or browse on it despite doing 35000 naira data subscription on it.                                                                                                                     │                           │                     │                │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ your 2 customer careline found on your website is not going as well to call from other network                                                                                                                                                            │                           │                     │                │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ 0802 150 0300                                                                                                                                                                                                                                             │                           │                     │                │
# │ 0802 152 0800                                                                                                                                                                                                                                             │                           │                     │                │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ reaching out to you through email only is appalling and your app is terrible.                                                                                                                                                                             │                           │                     │                │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ please help resolve this issue as soon as possible. i need my line to be working..                                                                                                                                                                        │                           │                     │                │
# │                                                                                                                                                                                                                                                           │                           │                     │                │
# │ i sent email [#2422436] to you no response up till now                                                                                                                                                                                                    │                           │                     │                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────────────────┼────────────────┤
# │
════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════╧═════════════════════╧══════════════════╛

# %%
import pandas as pd
import re
from tabulate import tabulate

# Load dataset
file_path = "final_airtel.csv"
df = pd.read_csv(file_path)

# Preprocessing function: convert text to lowercase, remove punctuation, and extra spaces
def preprocess_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespace
    return text

# Apply preprocessing to the commentText column
df["cleanedCommentText"] = df["commentText"].apply(preprocess_text)

# Define regex patterns for MyMTN-related feedback using word boundaries for accuracy
mymtn_patterns = [
           # matches "mymtn"
    r"\bapp\b",       # matches "mymtn app"
            # matches "mtn app"
    r"\bapplication\b", # matches "mtn application"
           # matches "mymtn ng"
]

# Function to check if a comment is related to MyMTN using the defined patterns
def is_mymtn_related(text):
    return any(re.search(pattern, text) for pattern in mymtn_patterns)

# Filter comments that are related to MyMTN/MTN app
df_mymtn = df[df["cleanedCommentText"].apply(is_mymtn_related)]

# Further filter only positive comments
df_mymtn_positive = df_mymtn[df_mymtn["sentiment/finalClassification"] == "positive"]

# Select the top 5 most positive comments based on sentiment/positiveScore
df_top_positive_mymtn = df_mymtn_positive.nlargest(20, "sentiment/positiveScore")[["commentAuthor", "commentText", "sentiment/positiveScore"]]

# Display results in a formatted table
print("\n=== Top 5 Most Positive Comments for MyMTN App ===")
print(tabulate(df_top_positive_mymtn, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# === Top 5 Most Positive Comments for MyMTN App ===
# ╒═════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════╕
# │ commentAuthor   │ commentText                                                                                                                                                                                                                                                                                                                                                                                                                  │   sentiment/positiveScore │
# ╞═════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════╡
# │ Gift Simire     │ GOOD EVENING GUY'S TODAY MASSIVE LEGIT WINNING GAMES ARE AVAILABLE ON SPORTY BET, BET9JA, MSPORT, BETKING ETC FOR SERIOUS SUBCRIBERS WHO ARE READY TO BE PART OF TO NIGHT GLOBAL SURE WINNING TIPS 💯💯💯                                                                                                                                                                                                                    │                  0.968595 │
# │                 │ CALL OR WHAT'S APP: +2348038539333                                                                                                                                                                                                                                                                                                                                                                                           │                           │
# ├─────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────┤
# │ Pro Bz          │ Hello!                                                                                                                                                                                                                                                                                                                                                                                                                       │                  0.945591 │
# │                 │ Amazing Deal!!!                                                                                                                                                                                                                                                                                                                                                                                                              │                           │
# │                 │ Enjoy exclusive offers from GTOPUP.                                                                                                                                                                                                                                                                                                                                                                                          │                           │
# │                 │ Get your DATA/AIRTIME for low for PER GB.                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │ Visit: sabuss.com/gtopup2                                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │ To enjoy.                                                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │                                                                                                                                                                                                                                                                                                                                                                                                                              │                           │
# │                 │ Android app available!                                                                                                                                                                                                                                                                                                                                                                                                       │                           │
# ├─────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────┤
# │ Pro Bz          │ Hello!                                                                                                                                                                                                                                                                                                                                                                                                                       │                  0.945591 │
# │                 │ Amazing Deal!!!                                                                                                                                                                                                                                                                                                                                                                                                              │                           │
# │                 │ Enjoy exclusive offers from GTOPUP.                                                                                                                                                                                                                                                                                                                                                                                          │                           │
# │                 │ Get your DATA/AIRTIME for low for PER GB.                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │ Visit: sabuss.com/gtopup2                                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │ To enjoy.                                                                                                                                                                                                                                                                                                                                                                                                                    │                           │
# │                 │                                                                                                                                                                                                                                                                                                                                                                                                                              │                           │
# │                 │ Android app available!                                                                                                                                                                                                                                                                                                                                                                                                       │                           │
# ├─────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────