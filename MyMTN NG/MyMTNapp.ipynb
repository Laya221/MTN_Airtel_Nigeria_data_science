# %%
import pandas as pd

# Load your Facebook dataset (update with your actual file path)
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)
print(df)
# Out:
#                commentAuthor  commentLikesCount  \
# 0          Ikechukwu Agudile                  0
# 1             Hippolyte Adja                  1
# 2                Bros Kelvin                  0
# 3             Kehshiy Makata                  0
# 4               Adam M Sharu                  0
# ...                      ...                ...
# 20025           Itz Oga Ebuz                  0
# 20026  Andrew Adejoh Opaluwa                  0
# 20027   Iyowuna Henry Cookey                  0
# 20028  Tada Hanka Leematukar                  0
# 20029            Ayei Ibiang                  0
#
#                                              commentText  \
# 0      Yes let's go make a difference go mad with MTN...
# 1                                        MTN Nigeriaa🤟🤞🥰
# 2                                                   😒😒😒😒
# 3      Network of life\nPls have a change of heart......
# 4                                                    👍🤳🤳
# ...

# %%
import pandas as pd

# Load your Facebook dataset (update with your actual file path)
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Ensure text columns are strings and handle NaN values
df.fillna("", inplace=True)

# Define search terms
search_terms = ["MyMTN", "MyMTN app","app","application","mtn application","APP","App","mymtn","myMTN","Application","MTN application", "mtn app", "mymtn ng", "mtn nigeria app"]

# Filter posts that mention "MyMTN" or "MyMTN app"
posts_with_mymtn = df[df["postDescription"].str.contains("|".join(search_terms), case=False, na=False)]

# Filter comments that mention "MyMTN" or "MyMTN app"
comments_with_mymtn = df[df["commentText"].str.contains("|".join(search_terms), case=False, na=False)]

# Save results
posts_with_mymtn.to_csv("filtered_posts_mymtn.csv", index=False)
comments_with_mymtn.to_csv("filtered_comments_mymtn.csv", index=False)

# Display summary
print(f"Filtered {len(posts_with_mymtn)} posts and {len(comments_with_mymtn)} comments mentioning 'MyMTN' or 'MyMTN app'.")
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_16232\550841538.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("", inplace=True)
# Filtered 2944 posts and 1976 comments mentioning 'MyMTN' or 'MyMTN app'.

# %%
import pandas as pd

# تحميل ملف التعليقات
file_path = "filtered_comments_mymtn.csv"
df = pd.read_csv(file_path)

# إزالة التعليقات التي كتبها "MTN Nigeria"
df = df[df["commentAuthor"] != "MTN Nigeria"]

# حفظ الملف بعد التنظيف
df.to_csv("filtered_comments_mymtn_cleaned.csv", index=False)

# عرض ملخص بعد الحذف
print(f"تمت إزالة جميع التعليقات التي كتبها 'MTN Nigeria'. الحجم الجديد للبيانات: {len(df)} صفوف.")
# Out:
# تمت إزالة جميع التعليقات التي كتبها 'MTN Nigeria'. الحجم الجديد للبيانات: 1932 صفوف.

# %%
import pandas as pd

# تحميل ملف التعليقات
file_path = "filtered_posts_mymtn.csv"
df = pd.read_csv(file_path)

# إزالة التعليقات التي كتبها "MTN Nigeria"
df = df[df["commentAuthor"] != "MTN Nigeria"]

# حفظ الملف بعد التنظيف
df.to_csv("filtered_posts_mymtn_cleaned.csv", index=False)

# عرض ملخص بعد الحذف
print(f"تمت إزالة جميع التعليقات التي كتبها 'MTN Nigeria'. الحجم الجديد للبيانات: {len(df)} صفوف.")
unique_lengths = df.nunique()

print(unique_lengths)
# Out:
# تمت إزالة جميع التعليقات التي كتبها 'MTN Nigeria'. الحجم الجديد للبيانات: 2941 صفوف.
# commentAuthor                    2349
# commentLikesCount                  17
# commentText                      2585
# commentTimestamp                 2934
# postCommentsCount                  38
# postDescription                    39
# postLikesCount                     35
# postTimestamp                      39
# postUrl                            39
# profileDescription                  0
# profileFollowers                    1
# profileName                         1
# profileUrl                          1
# sentiment/finalClassification       3
# sentiment/finalScore             2592
# sentiment/negativeScore          2596
# sentiment/neutralScore           2595
# sentiment/positiveScore          2593
# targetPlatform                      1
# dtype: int64

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)  # لعرض جميع القيم بدون اختصار

df = pd.read_csv('filtered_comments_mymtn.csv')

# استخراج القيم الفريدة وترتيبها أبجديًا
unique_authors = sorted(df['commentAuthor'].dropna().unique())  # إزالة القيم الفارغة إن وجدت

# طباعة القيم الفريدة مرتبة أبجديًا
for author in unique_authors:
    print(author)
# Out:
#  Adam Habib Abdulkadir 󱢏
# A Basi Ofon
# Abba Mohammed
# Abba Zr
# Abdmalik Olambiwonnu
# Abdsalam Ikram
# Abdul Ganiyu
# AbdulKabir Abu Bareerah
# Abdulazeez Ayodiran Adedokun
# Abdulazez Garba Usman
# Abdullahi Bello
# Abdullahi Jibril
# Abdullahi Lekan
# Abdullahi Yusup Siasia
# Abdullateef Temako Ishaq
# Abdulqadir Ahmad
# Abdulrahman Muhammad Jamiu
# Abdulrashid S Garba
# Abdulwahab Mahmud
# Abel BelKnow Ezekiel
# Abel Vwegba Bernard
# Abi Gail
# Abigail Sophia
# Abigeal Adesoji
# Abimbola Akinola-Lawal
# Abimbola Jeffery Uwatomo
# Abiodun Adegboye
# Abisayo Olapeju
# Abisola Adewumi
# Abolaji Ibrahim
# Abolore Aridunnu
# Abu Michael Danjuma
# Abubakar Abdullahi
# Abubakar Ali Tiffi
# Abubakar Bello
# Abubakar Hamza Naibi
# Abubakar Mustapha
# Abubakar Sadiq Bn Jibrin
# Adaido Ugherebe
# Adam M Sharu
# Adam Yakub
# Adamu Ahmad Maigana
# Adamu Aminu
# Adamu Ibrahim
# Adannaya Ist
# Adanu Israel
# Ade Doyin Ipadeola
# Ade Sunday
# Adebayo Lukman
# Adebimpe Flora
# Adebisi Adejoke
# ...

# %%
import pandas as pd

# تحميل البيانات
df = pd.read_csv('filtered_comments_mymtn.csv')

# البحث عن الصفوف التي يكون فيها commentAuthor يساوي "MTN Nigeria"
filtered_df = df[df['commentAuthor'] == 'MTN Nigeria']

# طباعة النتائج
print(filtered_df)

# حفظ النتائج في ملف CSV إذا لزم الأمر
filtered_df.to_csv('mtn_nigeria_comments.csv', index=False)
# Out:
#      commentAuthor  commentLikesCount  \
# 783    MTN Nigeria                  0
# 784    MTN Nigeria                  0
# 785    MTN Nigeria                  0
# 786    MTN Nigeria                  0
# 788    MTN Nigeria                  0
# 791    MTN Nigeria                  0
# 796    MTN Nigeria                  4
# 797    MTN Nigeria                  1
# 798    MTN Nigeria                  0
# 799    MTN Nigeria                  0
# 801    MTN Nigeria                  0
# 802    MTN Nigeria                  0
# 807    MTN Nigeria                  0
# 812    MTN Nigeria                  0
# 813    MTN Nigeria                  0
# 814    MTN Nigeria                  0
# 815    MTN Nigeria                  0
# 816    MTN Nigeria                  0
# 817    MTN Nigeria                  1
# 819    MTN Nigeria                  0
# 820    MTN Nigeria                  0
# 821    MTN Nigeria                  0
# 822    MTN Nigeria                  1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('filtered_comments_mymtn_cleaned.csv')

# Convert the commentTimestamp to datetime
df['commentTimestamp'] = pd.to_datetime(df['commentTimestamp'])

# Extract the month from the timestamp
df['month'] = df['commentTimestamp'].dt.to_period('M')

# Group by month and sentiment, then count the occurrences
sentiment_counts = df.groupby(['month', 'sentiment/finalClassification']).size().unstack(fill_value=0)

# Convert Period to string for plotting
sentiment_counts.index = sentiment_counts.index.astype(str)

# Define a color scheme
colors = {'positive': 'green', 'neutral': 'blue', 'negative': 'red'}

# Plot the data
ax = sentiment_counts.plot(kind='bar', stacked=True, figsize=(14, 8), color=[colors[col] for col in sentiment_counts.columns])

# Add annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    if height > 0:  # Only annotate bars with height > 0
        ax.annotate(f'{int(height)}', (x + width / 2, y + height / 2), ha='center', va='center', fontsize=9, color='white')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Improve title and labels
plt.title('Monthly Sentiment Distribution of MyMTN Comments', fontsize=16, pad=20)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Comments', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust legend position and style
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_12744\706508156.py:11: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['month'] = df['commentTimestamp'].dt.to_period('M')

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('filtered_comments_mymtn.csv')

# Define keywords for each subcategory
app_stability_keywords = [
    "crash", "unresponsive", "session timeout", "login issue", "freeze", "lag", "slow"
]

account_sync_keywords = [
    "transaction delay", "balance discrepancy", "missing transaction", "sync issue", "balance not updating"
]

payment_processing_keywords = [
    "failed transaction", "temporary deduction", "duplicate charge", "refund delay", "payment issue"
]

# Function to categorize comments based on keywords
def categorize_comment(comment):
    comment = comment.lower()
    if any(keyword in comment for keyword in app_stability_keywords):
        return "App Stability"
    elif any(keyword in comment for keyword in account_sync_keywords):
        return "Account Synchronization"
    elif any(keyword in comment for keyword in payment_processing_keywords):
        return "Payment Processing"
    else:
        return None

# Apply the categorization function to the comments
df['category'] = df['commentText'].apply(categorize_comment)

# Filter out comments that are not related to MyMTN technical issues
technical_issues_df = df[df['category'].notna()]

# Group comments by category and include comment author
grouped_comments = technical_issues_df.groupby('category').apply(
    lambda x: x[['commentAuthor', 'commentText']].to_dict('records')
).reset_index(name='comments')

# Display the results
for index, row in grouped_comments.iterrows():
    print(f"Category: {row['category']}")
    print("Comments:")
    for comment in row['comments']:
        print(f"- Author: {comment['commentAuthor']}")
        print(f"  Comment: {comment['commentText']}")
    print("\n" + "="*50 + "\n")
# Out:
# Category: App Stability
# Comments:
# - Author: Kenny Bayo Paul
#   Comment: MTN Nigeria YOUR APP IS SO VERY SLOW. IT TAKE ALMMOST 45MINS TO CARRY OUT TRANSACTIONS ON IT. THIS STATRTED SINCE YOU LUNCHED THE NEW ONE. WHAT IS THE USE OF A NEW APP THAT IS VERY SLOW? IT FAILS IN THE BASIS OF WHAT A GOOD APP IS. YOU PEOPLE HAVE TO WORK ON IT OR YOU ARE GRADUALLY LOOSING YOUR CUSTOMERS.
# - Author: Sandra Donalds Flournoy
#   Comment: I'm in Lagos Nigeria for the first time. I find MTN is a horrible service.
# While I'm here I'm watching the Nigerian news and I see the rates going up 50 to 70% and the excuse is tariffs.
#
# I didn't know that you could apply at tariff to a service.
#
# How can you justify that type of increase with the same pathetic useless terrible service?
#
# Don't you plan on making the service much better in order to deserve the increase?
# - Author: Chisom Princewill David
#   Comment: Don't let Nedu d!e😭
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords
categories = {
    "App Stability": [
        "crash", "unresponsive", "freeze", "lag", "slow", "session timeout", "loading issue"
    ],
    "Account Synchronization": [
        "delay", "not updated", "incorrect balance", "missing transaction", "sync issue"
    ],
    "Payment Processing": [
        "failed transaction", "deduction", "duplicate charge", "refund", "receipt issue"
    ]
}

# Function to categorize comments
def categorize_comment(text):
    for category, keywords in categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_comment)

# Filter for MyMTN-related comments
mymtn_keywords = ["MyMTN", "MyMTN app","app","application","mtn application","APP","App","mymtn","myMTN","Application","MTN application", "mtn app", "mymtn ng", "mtn nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_categorized_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of Comments by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of Comments by Category", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_8380\2700968505.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === App Stability ===
# ...

# %%
df_category
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords for User Experience Issues
user_experience_categories = {
    "Authentication": [
        "password", "otp", "one-time password", "verification code", "login issue", "account locked"
    ],
    "User Interface": [
        "cluttered", "too many ads", "difficult to use", "navigation issue", "hard to find", "menu problem"
    ],
    "Updates & Maintenance": [
        "update issue", "forced update", "app update", "compatibility issue", "maintenance", "service interruption"
    ]
}

# Function to categorize comments based on user experience issues
def categorize_user_experience(text):
    for category, keywords in user_experience_categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_user_experience)

# Filter for MyMTN-related comments
mymtn_keywords = ["MyMTN", "MyMTN app","app","application","mtn application","APP","App","mymtn","myMTN","Application","MTN application", "mtn app", "mymtn ng", "mtn nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Remove "Other" category
df_mymtn_filtered = df_mymtn_filtered[df_mymtn_filtered["category"] != "Other"]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_user_experience_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of User Experience Issues in MyMTN App", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of User Experience Issues", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in user_experience_categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_8380\342503053.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === Authentication ===
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════╤═════════════════════╤════════════════╕
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Ensure text data is treated as string and lowercase for consistency
df["commentText"] = df["commentText"].astype(str).str.lower()

# Define category keywords for Customer Support
customer_support_categories = {
    "In-app Support": [
        "self-service", "response time", "no response", "customer support", "chatbot", "live support", "help center"
    ],
    "Issue Resolution": [
        "ticket", "support tracking", "issue report", "no resolution", "problem not fixed", "open support ticket"
    ]
}

# Function to categorize comments based on customer support issues
def categorize_customer_support(text):
    for category, keywords in customer_support_categories.items():
        if any(keyword in text for keyword in keywords):
            return category
    return "Other"

# Apply categorization
df["category"] = df["commentText"].apply(categorize_customer_support)

# Filter for MyMTN-related comments
mymtn_keywords = ["MyMTN", "MyMTN app","app","application","mtn application","APP","App","mymtn","myMTN","Application","MTN application", "mtn app", "mymtn ng", "mtn nigeria app"]
df_mymtn = df[df["commentText"].str.contains("|".join(mymtn_keywords), na=False, regex=True)]

# Select relevant columns
df_mymtn_filtered = df_mymtn[["commentText", "commentAuthor", "commentLikesCount", "category"]]

# Remove "Other" category
df_mymtn_filtered = df_mymtn_filtered[df_mymtn_filtered["category"] != "Other"]

# Save categorized MyMTN comments
df_mymtn_filtered.to_csv("mymtn_customer_support_comments.csv", index=False)

# Count comments per category for visualization
category_counts = df_mymtn_filtered["category"].value_counts()

# === PLOTTING ===

# Bar chart for category distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
plt.title("Distribution of Customer Support Issues in MyMTN App", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Number of Comments", fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Pie chart for category distribution
plt.figure(figsize=(6, 6))
category_counts.plot.pie(autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Percentage of Customer Support Issues", fontsize=14)
plt.ylabel("")  # Hide y-label
plt.show()

# === DISPLAY TABLES WITH ENHANCED FORMATTING ===
for category in customer_support_categories.keys():
    df_category = df_mymtn_filtered[df_mymtn_filtered["category"] == category].sort_values(by="commentLikesCount", ascending=False)
    
    if not df_category.empty:
        print(f"\n=== {category} ===")
        print(tabulate(df_category, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_8380\3678986929.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette="coolwarm")
# === In-app Support ===
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════╤═════════════════════╤════════════════╕
# ...

# %%
df_category
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    commentText  \
# ...

# %%
import pandas as pd
import re
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Convert text to lowercase for uniformity
df["commentText"] = df["commentText"].astype(str).str.lower()

# Remove special characters and extra spaces
df["commentText"] = df["commentText"].apply(lambda x: re.sub(r'[^\w\s]', '', x).strip())

# Define keywords for MyMTN-related feedback
mymtn_keywords = [
    "mymtn", "mymtn app", "mtn app", "mtn application", "mymtn ng", "mtn nigeria app",
    "application", "mobile app", "mtn service app"
]

# Filter comments related to MyMTN app
df_mymtn = df[df["commentText"].str.contains(r'\b(' + '|'.join(mymtn_keywords) + r')\b', na=False, regex=True)]

# Further filter only strong positive comments (Threshold: > 0.8)
df_mymtn_positive = df_mymtn[df_mymtn["sentiment/positiveScore"] > 0.8]

# Select the top 5 most positive comments based on sentiment score & likes
df_top_positive_mymtn = df_mymtn_positive.nlargest(5, ["sentiment/positiveScore", "commentLikesCount"])[
    ["commentAuthor", "commentText", "sentiment/positiveScore", "commentLikesCount"]
]

# Display results in a formatted table
print("\n=== Top 5 Most Positive Comments for MyMTN App ===")
print(tabulate(df_top_positive_mymtn, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_8380\2143019287.py:22: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_mymtn = df[df["commentText"].str.contains(r'\b(' + '|'.join(mymtn_keywords) + r')\b', na=False, regex=True)]
# === Top 5 Most Positive Comments for MyMTN App ===
# ╒═══════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════╤═════════════════════╕
# │ commentAuthor     │ commentText                                                                                                                                                                                                                          │   sentiment/positiveScore │   commentLikesCount │
# ...

# %%
df_top_positive_mymtn
# Out:
#            commentAuthor  \
# 19289  Tiz Paul Williams
# 13153            Ais Osa
#
#                                                                                                                                                                                                                                 commentText  \
# 19289                                                                                                                                                                                                                     mymtn best so far
# 13153  bitcoin on the rise  investments are currently going on you can earn up to 55 interest rate of whatever you invest in less than 12 hrs few slots remaining click on the whatsapp link for application httpswamemessagecs6rfvmvbu54d1
#
#        sentiment/positiveScore  commentLikesCount
# 19289                  0.96534                  0
# 13153                  0.85507                  0

# %%
import pandas as pd
import re
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Preprocessing function: convert text to lowercase, remove punctuation, and extra spaces
def preprocess_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespace
    return text

# Apply preprocessing to the commentText column
df["cleanedCommentText"] = df["commentText"].apply(preprocess_text)

# Define regex patterns for MyMTN-related feedback using word boundaries for accuracy
mymtn_patterns = [
    r"\bmymtn\b",           # matches "mymtn"
    r"\bmymtn app\b",       # matches "mymtn app"
    r"\bmtn app\b",         # matches "mtn app"
    r"\bmtn application\b", # matches "mtn application"
    r"\bmymtn ng\b"         # matches "mymtn ng"
]

# Function to check if a comment is related to MyMTN using the defined patterns
def is_mymtn_related(text):
    return any(re.search(pattern, text) for pattern in mymtn_patterns)

# Filter comments that are related to MyMTN/MTN app
df_mymtn = df[df["cleanedCommentText"].apply(is_mymtn_related)]

# Further filter only positive comments
df_mymtn_positive = df_mymtn[df_mymtn["sentiment/finalClassification"] == "positive"]

# Select the top 5 most positive comments based on sentiment/positiveScore
df_top_positive_mymtn = df_mymtn_positive.nlargest(5, "sentiment/positiveScore")[["commentAuthor", "commentText", "sentiment/positiveScore"]]

# Display results in a formatted table
print("\n=== Top 5 Most Positive Comments for MyMTN App ===")
print(tabulate(df_top_positive_mymtn, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# === Top 5 Most Positive Comments for MyMTN App ===
# ╒═══════════════════╤═══════════════════╤═══════════════════════════╕
# │ commentAuthor     │ commentText       │   sentiment/positiveScore │
# ╞═══════════════════╪═══════════════════╪═══════════════════════════╡
# │ Tiz Paul Williams │ MyMTN Best so far │                   0.96534 │
# ╘═══════════════════╧═══════════════════╧═══════════════════════════╛

# %%
import pandas as pd
from tabulate import tabulate

# Load dataset
file_path = "filtered_comments_mymtn.csv"
df = pd.read_csv(file_path)

# Ensure sentiment scores are numeric
df["sentiment/positiveScore"] = pd.to_numeric(df["sentiment/positiveScore"], errors="coerce")

# Filter only positive comments
df_positive = df[df["sentiment/finalClassification"] == "positive"]

# Select the top 5 most positive comments based on positive sentiment score
df_top_positive = df_positive.nlargest(30, "sentiment/positiveScore")[["commentAuthor", "commentText", "sentiment/positiveScore"]]

# Display results in a formatted table
df_top_positive
# Out:
#                            commentAuthor  \
# 101                    Ikechukwu Agudile
# 1328                   Ikechukwu Agudile
# 599                    Ikechukwu Agudile
# 880                    Ikechukwu Agudile
# 576                    Ikechukwu Agudile
# 628                          Rabiu Aminu
# 657                    Ikechukwu Agudile
# 142                    Ikechukwu Agudile
# 423                    Ortema King Solex
# 1522                          Oyom Oyama
# 516                        Crypto Bishop
# 1872                    Adebowale Omooba
# 1673                   Theophilus Cosmas
# 330                              Bro Ben
# 1572                   Clemant Agbakossi
# 676                         Itz Billionz
# 578                    Pherrary Pherrary
# 627                        Wisdom Anyang
# 100                       Elizabeth Emah
# 1039                        Jamil Editor
# 1901  Olokuntoye Akindoyin Sunday Fasasi
# 1466                          Laura Duel
# ...

# %%
import pandas as pd
import re
from tabulate import tabulate

# Load dataset
file_path = "final_mtn.csv"
df = pd.read_csv(file_path)

# Preprocessing function: convert text to lowercase, remove punctuation, and extra spaces
def preprocess_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespace
    return text

# Apply preprocessing to the commentText column
df["cleanedCommentText"] = df["commentText"].apply(preprocess_text)

# Define regex patterns for MyMTN-related feedback using word boundaries for accuracy
mymtn_patterns = [
           # matches "mymtn"
    r"\bapp\b",       # matches "mymtn app"
            # matches "mtn app"
    r"\bapplication\b", # matches "mtn application"
           # matches "mymtn ng"
]

# Function to check if a comment is related to MyMTN using the defined patterns
def is_mymtn_related(text):
    return any(re.search(pattern, text) for pattern in mymtn_patterns)

# Filter comments that are related to MyMTN/MTN app
df_mymtn = df[df["cleanedCommentText"].apply(is_mymtn_related)]

# Further filter only positive comments
df_mymtn_positive = df_mymtn[df_mymtn["sentiment/finalClassification"] == "positive"]

# Select the top 5 most positive comments based on sentiment/positiveScore
df_top_positive_mymtn = df_mymtn_positive.nlargest(20, "sentiment/positiveScore")[["commentAuthor", "commentText", "sentiment/positiveScore"]]

# Display results in a formatted table
print("\n=== Top 5 Most Positive Comments for MyMTN App ===")
print(tabulate(df_top_positive_mymtn, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# === Top 5 Most Positive Comments for MyMTN App ===
# ╒════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════╕
# ...
