# %%
import pandas as pd
df2=pd.read_csv('airtel_post_analysis.csv')
#df=pd.read_csv('../Datasets/1airtel_posts_final.csv')

# %%
#df.head()

# %%
#df.columns

# %%
#df2 = df[['postId','pageName', 'comments','isVideo','likes','media/0/__typename','shares','text','time','timestamp','url','viewsCount',]]
#df2.to_csv('airtel_post_analysis.csv', index=False)  # Set index=False to avoid writing row indices

# %%
df2.head()
# Out:
#              postId  pageName  comments isVideo  likes media/0/__typename  \
# 0  1015157180643643  airtelng       237     NaN    101              Photo
# 1  1014358040723557  airtelng       171     NaN    106              Photo
# 2  1010288771130484  airtelng       428    True    140              Video
# 3  1008795054613189  airtelng       676     NaN    276              Photo
# 4  1004649415027753  airtelng       380    True    153              Video
#
#    shares                                               text  \
# 0       6  Unwrap endless fun this season with our 4G Sma...
# 1       5  Countdown to Christmas🎄\n\nUnlimited Data + 6-...
# 2       1  Stream more, worry less! \n\nLearn how to save...
# 3      10  With our social media bundles, the fun never s...
# 4       6  Today, we celebrate the strength, sacrifice, a...
#
#                        time   timestamp  \
# 0  2024-12-03T14:07:56.000Z  1733234876
# 1  2024-12-02T14:07:13.000Z  1733148433
# 2  2024-11-27T08:11:15.000Z  1732695075
# 3  2024-11-25T07:17:11.000Z  1732519031
# 4  2024-11-19T15:32:21.000Z  1732030341
#
#                                                  url  viewsCount
# 0  https://www.facebook.com/airtelng/posts/pfbid0...         NaN
# 1  https://www.facebook.com/airtelng/posts/pfbid0...         NaN
# 2     https://www.facebook.com/reel/586901850470448/      1404.0
# 3  https://www.facebook.com/airtelng/posts/pfbid0...         NaN
# 4     https://www.facebook.com/reel/573626148685675/      2118.0

# %%
total_likes = df2['likes'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total likes for all:", total_likes)
# Out:
# Total likes for all: 87469

# %%
total_comments = df2['comments'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total comments for all:", total_comments)
# Out:
# Total comments for all: 13668

# %%
total_shares = df2['shares'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total shares for all:", total_shares)
# Out:
# Total shares for all: 773

# %%
# Sort the dataframe by the 'likes' column in descending order
sorted_df = df2.sort_values(by='likes', ascending=False)

# Get the top 5 posts
top_5_posts = sorted_df.head(5)

# Display the result
print("Top 5 posts with the highest likes:")
print(top_5_posts[['text', 'likes','url','time','media/0/__typename']])
# Out:
# Top 5 posts with the highest likes:
#                                                  text  likes  \
# 5   Unlimited possibilities with unlimited data! \...  35741
# 9   It's screaming steeeeeeze!!! \n\nGet the best ...  10793
# 28  Get hours of access to your favourite social p...  10532
# 35  Get the best of both worlds with Airtel VoLTE,...   6393
# 36  New phone, new data perks!\n\nSlot in your Air...   4565
#
#                                                   url  \
# 5   https://www.facebook.com/airtelng/posts/pfbid0...
# 9      https://www.facebook.com/reel/850787246924681/
# 28  https://www.facebook.com/airtelng/posts/pfbid0...
# 35  https://www.facebook.com/airtelng/posts/pfbid0...
# 36  https://www.facebook.com/airtelng/posts/pfbid0...
#
#                         time media/0/__typename
# 5   2024-11-18T13:29:17.000Z              Photo
# 9   2024-11-05T14:10:54.000Z              Video
# 28  2024-09-05T10:36:10.000Z              Photo
# 35  2024-08-14T07:37:35.000Z              Photo
# 36  2024-08-13T18:21:17.000Z              Photo

# %%
# Sort the dataframe by the 'likes' column in descending order
sorted_df = df2.sort_values(by='comments', ascending=False)

# Get the top 5 posts
top_5_posts = sorted_df.head(5)

# Display the result
print("Top 5 posts with the highest comments:")
print(top_5_posts[['text', 'comments','url','time','media/0/__typename']])
# Out:
# Top 5 posts with the highest comments:
#                                                  text  comments  \
# 29  Can you arrange the words correctly? \n\nRepos...       921
# 28  Get hours of access to your favourite social p...       751
# 5   Unlimited possibilities with unlimited data! \...       751
# 3   With our social media bundles, the fun never s...       676
# 9   It's screaming steeeeeeze!!! \n\nGet the best ...       647
#
#                                                   url  \
# 29  https://www.facebook.com/airtelng/posts/pfbid0...
# 28  https://www.facebook.com/airtelng/posts/pfbid0...
# 5   https://www.facebook.com/airtelng/posts/pfbid0...
# 3   https://www.facebook.com/airtelng/posts/pfbid0...
# 9      https://www.facebook.com/reel/850787246924681/
#
#                         time media/0/__typename
# 29  2024-08-22T16:37:03.000Z              Photo
# 28  2024-09-05T10:36:10.000Z              Photo
# 5   2024-11-18T13:29:17.000Z              Photo
# 3   2024-11-25T07:17:11.000Z              Photo
# 9   2024-11-05T14:10:54.000Z              Video

# %%
# إضافة عمود جديد يحتوي على مجموع الإعجابات والتعليقات
df2['total_likes_comments'] = df2['likes'] + df2['comments']

# ترتيب الـ DataFrame بناءً على مجموع الإعجابات والتعليقات
sorted_df = df2.sort_values(by='total_likes_comments', ascending=False)

# الحصول على أعلى 5 منشورات
top_5_posts = sorted_df.head(5)

# عرض النتيجة كجدول
top_5_table = top_5_posts[['text', 'likes', 'comments', 'total_likes_comments', 'url', 'time', 'media/0/__typename']]
print(top_5_table)
# Out:
#                                                  text  likes  comments  \
# 5   Unlimited possibilities with unlimited data! \...  35741       751
# 9   It's screaming steeeeeeze!!! \n\nGet the best ...  10793       647
# 28  Get hours of access to your favourite social p...  10532       751
# 35  Get the best of both worlds with Airtel VoLTE,...   6393       453
# 25  Protect your gadgets with PicknFix!\n\nGet fre...   4383       440
#
#     total_likes_comments                                                url  \
# 5                  36492  https://www.facebook.com/airtelng/posts/pfbid0...
# 9                  11440     https://www.facebook.com/reel/850787246924681/
# 28                 11283  https://www.facebook.com/airtelng/posts/pfbid0...
# 35                  6846  https://www.facebook.com/airtelng/posts/pfbid0...
# 25                  4823  https://www.facebook.com/airtelng/posts/pfbid0...
#
#                         time media/0/__typename
# 5   2024-11-18T13:29:17.000Z              Photo
# 9   2024-11-05T14:10:54.000Z              Video
# 28  2024-09-05T10:36:10.000Z              Photo
# 35  2024-08-14T07:37:35.000Z              Photo
# 25  2024-09-23T14:13:16.000Z              Photo

# %%
print(len(df2))
# Out:
# 55

# %%
import matplotlib.pyplot as plt

# Step 2: Convert the timestamp column to datetime
df2['time'] = pd.to_datetime(df2['time'])  # Replace 'time' with your actual timestamp column name

# Step 3: Filter for the year 2024
df_2024 = df2[df2['time'].dt.year == 2024]

# Step 4: Group by month and count the number of posts
monthly_counts = df_2024.groupby(df_2024['time'].dt.month).size()

# Step 5: Plotting the results
plt.figure(figsize=(5, 5))
monthly_counts.plot(kind='bar', color='red', alpha=0.8, edgecolor='black', linewidth=1)
plt.title('Number of Airtel Posts per Month in 2024', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.xticks(ticks=range(5), labels=['Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('airtel_post_month.png', format='png', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame and it has been defined earlier
# Step 1: Convert the timestamp column to datetime
df2['time'] = pd.to_datetime(df2['time'])  # Replace 'time' with your actual timestamp column name

# Step 2: Filter for the date range from August 1, 2024, to December 5, 2024
start_date = '2024-08-01'
end_date = '2024-12-05'
df_filtered = df2[(df2['time'] >= start_date) & (df2['time'] <= end_date)]

# Step 3: Group by day and count the number of posts
daily_counts = df_filtered.groupby(df_filtered['time'].dt.date).size()

# Step 4: Prepare data for plotting
dates = daily_counts.index
counts = daily_counts.values

# Step 5: Create the plot
plt.figure(figsize=(12, 6))
plt.plot(dates, counts, marker='o', linestyle='-', color='red', alpha=0.7)

# Step 6: Add titles and labels
plt.title('Airtel Posts per Day from Aug 1, 2024 to Dec 5, 2024', fontsize=16, fontweight='bold')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')  # Add a horizontal line at y=0
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Step 7: Save and show the plot
plt.savefig('airtel_day_posts.png', format='png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\LCT\AppData\Local\Temp\ipykernel_18980\2297652494.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['time'] = pd.to_datetime(df2['time'])  # Replace 'time' with your actual timestamp column name

# %%
reels_df = df2[df2['url'].str.startswith('https://www.facebook.com/reel/', na=False)]

# Step 3: Save the filtered DataFrame to a new CSV file
reels_df.to_csv('airtel_reels.csv', index=False)  # Set index=False to avoid writing row indices

# %%
print(len(reels_df))
# Out:
# 20

# %%
posts_df = df2[df2['url'].str.startswith('https://www.facebook.com/airtelng/', na=False)]

# Step 3: Save the filtered DataFrame to a new CSV file
posts_df.to_csv('airtel_just_posts.csv', index=False)  # Set index=False to avoid writing row indices

# %%
print(len(posts_df))
# Out:
# 35

# %%
total_likes = posts_df['likes'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total likes for posts:", total_likes)
# Out:
# Total likes for posts: 73813

# %%
total_comments = posts_df['comments'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total comments for post:", total_comments)
# Out:
# Total comments for post: 10453

# %%
total_likes = reels_df['likes'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total likes for reels:", total_likes)
# Out:
# Total likes for reels: 13656

# %%
total_comments = reels_df['comments'].sum()  # Replace 'likes' with the actual name of your likes column

# Step 3: Print the total likes
print("Total comments for reels:", total_comments)
# Out:
# Total comments for reels: 3215

# %%
import matplotlib.pyplot as plt

# Step 2: Convert the timestamp column to datetime
df2['time'] = pd.to_datetime(df2['time'])  # Replace 'time' with your actual timestamp column name

# Step 3: Filter for the year 2024
df_2024 = df2[df2['time'].dt.year == 2024]

# Step 4: Remove December
df_2024 = df_2024[df_2024['time'].dt.month != 12]

# Step 5: Group by month and count the number of posts
monthly_counts = df_2024.groupby(df_2024['time'].dt.month).size()

# Step 6: Plotting the results
plt.figure(figsize=(5, 5))
monthly_counts.plot(kind='bar', color='red', alpha=0.8, edgecolor='black', linewidth=1)
plt.title('Number of Airtel Posts per Month in 2024', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.xticks(ticks=range(len(monthly_counts)), labels=['Aug', 'Sep', 'Oct', 'Nov'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('airtel_post_month.png', format='png', bbox_inches='tight')

plt.show()
